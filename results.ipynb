# %%
from TwoStreamSimulation.PICFunctions import *

# %%
# # 1. Define Simulation
# c = gen_normalized_constants(
#     L_in_Debye=100, 
#     Time_in_Periods=20, 
#     particles_per_cell = 100
# )

# # 2. Calculate Optimal Drift, define x_critical from linear fluid analysis
# v_drift = calculate_optimal_v_beam(c)
# x_crit = 1.1573

# # Check CFL condition:
# print(f"CFL Condition (v_drift * dt / dx): {(v_drift * c['dt']) / c['dx']:.4f}")

# # Check minimum length condition 
# min_length = 2 * np.pi * v_drift / (c['omega_pe'] * x_crit)
# print(f"Minimum Length Condition: Simulation Length = {c['grid_length']:.2f}, Required Minimum Length = {min_length:.2f}")

# # 3. Initialize Particles
# x_e = np.random.rand(c['num_electrons']) * c['grid_length']

# # add thermal velocity to electrons. Since lambda_D * omega_pe = 1 = v_th, we must choose v_th_e = 1
# v_th_e = 1.0
# v_e = np.random.normal(loc=v_drift, scale = v_th_e, size = c['num_electrons'])

# # Ions
# x_i = np.random.rand(c['num_ions']) * c['grid_length']
# v_i = np.random.normal(0.0, 0.01, c['num_ions'])

# %%
# # 4. Run Simulation
# diagnostics = pic_simulation_with_ions(x_e, x_i, v_e, v_i, c, save_phase_space=True)

# %%
# 5. Plot First Results
# energy_conservation_plot(diagnostics, c['omega_pe'])

# plot_phase_space_evolution(diagnostics, c['omega_pe'], 
#                                 frame_indices=None, 
#                                 num_frames=6,
#                                 save_plots=True)

# %%
# plot_growth_rate(diagnostics, c['omega_pe'], linear_growth_rate=0.05437, fit_range=(0.2, 7))

# %%
# # Animation (Fixed to 45 seconds)
# plot_phase_space_animation_scatter(diagnostics, c['omega_pe'], save_animation=True, duration_sec=45)
